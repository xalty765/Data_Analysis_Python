# %% [markdown]
# # Exploratory Data Analysis on SuperStore

# %% [markdown]
# ## Introduction

# %% [markdown]
# Super Store is a small retail business located in the United States. They sell Furniture, Office Supplies and Technology products and their customers are the mass Consumer, Corporate and Home Offices. The data set contains sales, profit and geographical information of individual orders.
#
# Our task is to determine weak areas and opportunities for Super Store to boost business growth.
#
# #### Business Questions:
#
# -Which Category is Best Selling and Most Profitable?
#
# -What are the Best Selling and Most Profitable Sub-Category?
#
# -Which is the Top Selling Sub-Category?
#
# -Which Customer Segment is Most Profitable?
#
# -Which is the Preferred Ship Mode?
#
# -Which Region is the Most Profitable?
#
# -Which City has the Highest Number of Sales?

# %% [markdown]
# ### Preparing the Environment
#
# We will import the required libraries and read in the data set.
#
# Pandas - Data manipulation
#
# Matplotlib and Seaborn - Data visualisation

# %%
# Import necessary libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
superstore = pd.read_csv('SampleSuperstore.csv')

# %%
superstore
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## Data Exploration
# Let's have a look at the data using various pandas function.

# %%
#preview first 5 rows of the dataset
superstore.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#preview last 5 rows of the dataset
superstore.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
# names of the columns present in the dataset
superstore.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# You can easily tell that the dataset contains  various categorical,geographical an numerical variables.
#
# Each row represents an order of an item and the corresponding quantity, sales, discount and profit. There is also the mode of shipment, customer segment and geographical aspects.

# %%
#summarized information of the dataset
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# shape of the dataset
superstore.shape
# Out:
# (9994, 13)

# %%
# total values in the dataset
superstore.size
# Out:
# 129922

# %% [markdown]
# ## Data Cleaning
#
# Before we start with the analysis, we must first clean the data or "scrub the dirt".
#
# For this analysis, we will look at the more common issues such as missing and duplicate data.

# %%
# no of null or missing values in the dataset
superstore.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# As you can see there are no null or missing values in the dataset.

# %% [markdown]
# Now, let's check for duplicate values in the dataset.

# %%
# sum of duplicates in the dataset
superstore.duplicated().sum()
# Out:
# 17

# %% [markdown]
# As you can see there are 17 values in the dataset that are duplicates.
#
# So let's drop them from the dataset.

# %%
# dropping duplicate values
superstore.drop_duplicates(inplace = True)

# %%
# total rows after dropping the duplicates
superstore.shape
# Out:
# (9977, 13)

# %% [markdown]
# Alright!
#
# We can confirm that the duplicated rows have been dropped as the rows were 9993 before and now it's reduced to 9977 rows.

# %% [markdown]
# ## Statistical Analysis
#
# Here, we will do a descriptive statistical analysis. We use df.describe() and assign 'include = 'all' to ensure that categorical features are also included in the output.

# %%
# Statistical summary of the data 
superstore.describe(include ='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %% [markdown]
# Let's create a new column in the dataframe containing profit margin for each category.
#
# Profit Margin(%) = (Profit-Sales) * 100

# %%
superstore['Profit Margin %'] = (superstore.Profit / superstore.Sales) * 100
superstore.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit  Profit Margin %
# 0      0.00   41.9136            16.00
# ...

# %%
# Statistical summary of the data 
superstore.describe(include ='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %% [markdown]
# What we want to focus is the unique count and frequency of the categorical features such as
#
# 1. There are 4 ship modes and 3 customer segments.Nearly half of the orders are from Consumer segment using Standard Class shipment.
#
# 2. The store carries 3 category of items with 17 sub-category. 60% of orders are for Office Supplies and at least 15% purchases are for Binders.
#
#
# While for numerical parameters, it's interesting to note that the
#
# 1. 75% of orders makes at least 36% profit margin.
# 2. Loss-making orders can go up to 275% losses. We must place emphasis on these loss-making sales to cut them off.
#
# We will perform some analysis below to test these observations.

# %% [markdown]
# ## Analysis and Visualizations

# %% [markdown]
# ### 1. Which Category is Best Selling and Most Profitable?
#
# We will group the Sales, Profit and also Quantity by Category.

# %%
# grouping Sales, profit and quantity by category
category_analysis = pd.DataFrame(superstore.groupby(['Category'])[['Sales','Profit','Quantity']].sum())
category_analysis

# %%
# setting subplots
figure, axis = plt.subplots(1, 3, figsize=(20,10))

#plotting barcharts
category1 = sns.barplot(x =category_analysis.index,y =category_analysis.Sales,ax =axis[0])
category2 = sns.barplot(x =category_analysis.index,y =category_analysis.Profit,ax =axis[1])
category3 = sns.barplot(x =category_analysis.index,y =category_analysis.Quantity,ax =axis[2])

# Set titles
category1.set(title = 'Sales')
category2.set(title = 'Profit')
category3.set(title = 'Quantity')

# theme of the plot
sns.set_theme(style="darkgrid")

plt.show()

# %% [markdown]
# #### Our observations are:-
#
# 1- All 3 categories - Furniture, Office Supplies and Technology make similar amount of sales.
#
# 2- Technology is Best Selling and it's good to know that this category is also the Most Profitable category too.
#   Though minimal   quantity is sold in this category as these products are usually one-time purchases and can last for a long     time.
#
# 3- Although Furniture makes similar sales as Technology, it is the least profitable and quantity sold are at a minimum too.
#
# 4- Office Supplies sells the most in terms of quantity as it is relatively cheap product and are frequently purchased.

# %% [markdown]
# ### 2 - Which is the most selling Sub-Category?

# %%
# grouping quantity by sub-category
subcat_quantity = pd.DataFrame(superstore.groupby(['Sub-Category'])[['Quantity']].sum().sort_values('Quantity',ascending=False))
subcat_quantity
# Out:
#               Quantity
# Sub-Category
# Binders           5971
# Paper             5144
# Furnishings       3560
# Phones            3289
# Storage           3158
# Art               2996
# Accessories       2976
# Chairs            2351
# Appliances        1729
# Labels            1396
# Tables            1241
# Fasteners          914
# Envelopes          906
# Bookcases          868
# Supplies           647
# Machines           440
# Copiers            234

# %%
# ploting the sub-categories
sns.set_theme(style ='darkgrid')
sns.barplot(data = subcat_quantity, x =subcat_quantity.Quantity, y= subcat_quantity.index,palette ='tab10')
plt.title('Top Selling SubCategory')
plt.show()

# %% [markdown]
# #### Our Observations are: -
#
# As you can see the most items are being sold in the categories of Binders , Papers , Furnishings and Phones as these are frequently used and exhausted categories in various settings.
#
# So the management should ensure that the inventory is always well-stocked for these categories.
#
# Despite being most profitable, Copiers sell the least only 234, but as it is a relatively expensive office equipment that is usually used for few years, it is understandable that it sells the least among all.

# %% [markdown]
# ### 3. What are the Best Selling and Most Profitable Sub-Category?

# %%
# group by sales and profit sub-category
subcat_analysis = pd.DataFrame(superstore.groupby('Sub-Category')[['Sales','Profit']].sum())
subcat_analysis
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories   167380.3180  41935.6649
# Appliances    107532.1610  18138.0054
# Art            27107.0320   6524.6118
# Binders       203409.1690  30228.0003
# Bookcases     114879.9963  -3472.5560
# Chairs        327777.7610  26567.1278
# Copiers       149528.0300  55617.8249
# Envelopes      16476.4020   6964.1767
# Fasteners       3024.2800    949.5182
# Furnishings    91683.0240  13052.7230
# Labels         12444.9120   5526.3820
# Machines      189238.6310   3384.7569
# Paper          78224.1420  33944.2395
# Phones        330007.0540  44513.7306
# Storage       223843.6080  21278.8264
# Supplies       46673.5380  -1189.0995
# Tables        206964.5320 -17725.4811

# %%
# sorting by sales(descending)
subcat_sales =pd.DataFrame(subcat_analysis.sort_values('Sales',ascending =False))
subcat_sales
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        330007.0540  44513.7306
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Tables        206964.5320 -17725.4811
# Binders       203409.1690  30228.0003
# Machines      189238.6310   3384.7569
# Accessories   167380.3180  41935.6649
# Copiers       149528.0300  55617.8249
# Bookcases     114879.9963  -3472.5560
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Paper          78224.1420  33944.2395
# Supplies       46673.5380  -1189.0995
# Art            27107.0320   6524.6118
# Envelopes      16476.4020   6964.1767
# Labels         12444.9120   5526.3820
# Fasteners       3024.2800    949.5182

# %%
# sorting by profit
subcat_profit = pd.DataFrame(subcat_analysis.sort_values('Profit',ascending = False))
subcat_profit
# Out:
#                     Sales      Profit
# Sub-Category
# Copiers       149528.0300  55617.8249
# Phones        330007.0540  44513.7306
# Accessories   167380.3180  41935.6649
# Paper          78224.1420  33944.2395
# Binders       203409.1690  30228.0003
# Chairs        327777.7610  26567.1278
# Storage       223843.6080  21278.8264
# Appliances    107532.1610  18138.0054
# Furnishings    91683.0240  13052.7230
# Envelopes      16476.4020   6964.1767
# Art            27107.0320   6524.6118
# Labels         12444.9120   5526.3820
# Machines      189238.6310   3384.7569
# Fasteners       3024.2800    949.5182
# Supplies       46673.5380  -1189.0995
# Bookcases     114879.9963  -3472.5560
# Tables        206964.5320 -17725.4811

# %%
figure,axis= plt.subplots(1,2,figsize = (18,12))

# Plot Bar Plot for Best Selling Sub-Category
subcat1 = sns.barplot(data = subcat_sales, y = subcat_sales.index, x= subcat_sales.Sales, ax=axis[0] ,palette='rainbow')
subcat1.set_title('Best Selling Sub-Category')


# Plot Bar Plot for Most Profitable Sub-Category
subcat2 = sns.barplot(data = subcat_profit, y = subcat_profit.index, x = subcat_profit.Profit, ax=axis[1],palette='husl')
subcat2.set_title('Most Profitable Sub-Category')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Our Observations are:-
#
# Phones and Chairs are the best selling sub-category.
#
# Copiers produces most profit as they are pretty expensive followed by Phones, Accessories and  Papers . The marketing strategy is to focus on marketing these products.
#
# On the other end of the spectrum, Machines, Fasteners, Supplies, Bookcases and Tables make close to zero margin to losses.
# These are products that Super Store can consider dropping from the product catalogue or increase the sale price and profit margin or bargain for a lower price from the supplier.

# %% [markdown]
# ### 4. Which Customer Segment is Most Profitable?

# %%
# grouping by profit and sales on segments
segment_analysis = pd.DataFrame(superstore.groupby('Segment')[['Profit','Sales']].sum())
segment_analysis
# Out:
#                   Profit         Sales
# Segment
# Consumer     134004.4705  1.160832e+06
# Corporate     91954.9798  7.060701e+05
# Home Office   60279.0015  4.292927e+05

# %%
# plotting the segments
seg1 = sns.barplot(data = segment_analysis,x =segment_analysis.Profit,y =segment_analysis.index,palette ='tab10')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Our Observations are:-
#
# Consumer segment is most profitable, followed by Corporate Segment and Home Office. Hence, marketing strategy has to target or place more focus to retain more customers from Consumer and Corporate segments.

# %% [markdown]
# ### 5. Which is the Preferred Ship Mode?

# %%
# plotting shipment modes
sns.countplot(superstore['Ship Mode'],palette ='rocket')
plt.show()

# %% [markdown]
# #### Our Observations are:-
#
# As you can see that Standard Class is the preferred method of shipment by a long shot and perhaps the cheapest one too. The other modes are not much prefered among the customers as they  may be too expensive.

# %% [markdown]
# ### 6. Which Region is the Most Profitable?

# %%
# grouping by region
regional_analysis = pd.DataFrame(superstore.groupby('Region')['Profit'].sum().reset_index())
regional_analysis
# Out:
#     Region       Profit
# 0  Central   39653.8752
# 1     East   91506.3092
# 2    South   46749.4303
# 3     West  108328.8371

# %%
# plotting pie chart for regional sales and profit
explode = [ 0.1,0,0,0.2]

palette_color = sns.color_palette('coolwarm')

plt.pie(regional_analysis.Profit,labels = regional_analysis.Region ,startangle = 90,explode=explode, autopct='%.0f%%',shadow ='True',colors =palette_color)

plt.title('Most Profitable Region')
plt.show()

# %% [markdown]
# #### Our Observations:-
#
# As seen by the pie chart the eastern and the western regions are definitely the most profitable.

# %% [markdown]
# ### 7. Which City has the Highest Number of Sales?

# %%
# grouping by  sales , profit and quantity on city
city_sales = pd.DataFrame(superstore.groupby(['City'])['Sales', 'Profit','Quantity'].sum().sort_values('Sales',ascending = False))

top_sales = city_sales[:10]
top_sales
# Out:
#                      Sales      Profit  Quantity
# City
# New York City  256319.0410  62013.8973      3413
# Los Angeles    175831.9010  30430.4559      2876
# Seattle        119460.2820  29121.6825      1578
# San Francisco  112577.1720  17466.1186      1920
# Philadelphia   109061.4610 -13843.2106      1978
# Houston         64441.2564 -10175.1755      1460
# Chicago         48535.9770  -6648.3318      1129
# San Diego       47521.0290   6377.1960       670
# Jacksonville    44713.1830  -2323.8350       429
# Springfield     43054.3420   6200.6974       649

# %%
city_profit = pd.DataFrame(superstore.groupby(['City'])['Sales', 'Profit','Quantity'].sum().sort_values('Profit',ascending = False))

top_profit= city_profit[:10]
top_profit
# Out:
#                     Sales      Profit  Quantity
# City
# New York City  256319.041  62013.8973      3413
# Los Angeles    175831.901  30430.4559      2876
# Seattle        119460.282  29121.6825      1578
# San Francisco  112577.172  17466.1186      1920
# Detroit         42056.974  13146.6935       438
# Lafayette       25035.200  10018.3876       104
# Jackson         24963.858   7581.6828       318
# Atlanta         17197.840   6993.6629       156
# Minneapolis     16870.540   6824.5846        80
# San Diego       47521.029   6377.1960       670

# %%
figure, axis = plt.subplots(1, 2, figsize=(18, 6))

# plotting the top selling cities
top_sales1= sns.barplot(data = top_sales, y = top_sales.index, x = top_sales.Sales, palette = "rainbow", ax = axis[0])
top_sales1.set_title('Top 10 cities with Highest Sales')

# plotting the most profitable cities
top_profit1 = sns.barplot(data = top_profit, y = top_profit.index, x = top_profit.Profit, palette = "coolwarm", ax=axis[1])
top_profit1.set_title('Top 10 most Profitable cities')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Strategic Recommendation
#
# Let's share our business recommendations  for better future decisions.
#
# #### Recomendations:-
#
# Focus on Technology , Phones and Chairs sub-categories as they are highest selling and most profitable.
#
# Selling Bookcases and Tables result in huge losses, so Super Store has to consider to bundle them together with High Selling or Profitable sub-category such as Chairs, Copiers, Phones and Office Supplies products.
#
# For loss-making products like Supplies, Bookcases, Tables, consider to either drop these from the catalogue or change suppliers and bargain for cheaper price.
#
# Selling Bookcases and Tables result in huge losses, so Super Store has to consider to bundle them together with High Selling or Profitable sub-category such as Chairs, Copiers, Phones and Office Supplies products.
#
# For Home Offices customers, these people might be busy with work and less likely to spend time selecting individual products, so create a Home Office package with products used for offices such as table, chairs, phone, copiers, storage, label, fasteners, bookcases.
#
# Consumer and Corporate Segment make up more than 70% of customerbase. Target them, especially customers from the East and West region in the Top 10 cities with Highest Sales by introducing special promotions and bundles for mass Consumer and Home Offices and send promotional emails or flyers.
